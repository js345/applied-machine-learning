# %%
from pandas.tools.plotting import scatter_matrix
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("iris.data.txt", sep=",", skipinitialspace=True, skiprows=0, header=None)
colors = {"Iris-setosa":"red","Iris-versicolor":"blue","Iris-virginica":"green"}
scatter_matrix(df, alpha=1, figsize=(30,30),c=df.4.apply(lambda x:colors[x]))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119006b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115d10dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x102605810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1190d6490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x119155f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119118490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1192476d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1192cc890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11932dd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1193b0cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119416990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119497910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11951a790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119589990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11960c810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119671750>]], dtype=object)
